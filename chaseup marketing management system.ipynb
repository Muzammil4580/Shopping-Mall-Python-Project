# %%
print("**********************************************************************************************************")
print("**********************************************************************************************************")
print("**********************************************************************************************************")
print("******************************WELL COME TO CHASEUP MALL***************************************************")
print("**********************************************************************************************************")
print("**********************************************************************************************************")
print("**********************************************************************************************************")
print("**********************************************************************************************************")
class cashieringsystem:

    def __init__(self,a=0, r=0,recieve=0,change=0,temp=0,payment=0):

        print("\t***********************WELL COME TO THE WORLD OF BRANDS***********************************")
        print("\t******************************************************************************************")
        print("\t******************************************************************************************")
        print("\t******************************************************************************************")

        self.a = a
        self.r = r
        self.recieve = recieve
        self.change = change
        self.temp = temp
        self.pay = payment
    def shopping(self):
        print("*****WELL COME TO CHASEUP MALL*****")
        print("1.Shirt XS----->2000", "\n2.Shirt XL----->1800", "\n3.Jeans XS--->2200", "\n4.Jeans XL---->2600", "\n6.shoes---->1800","\n5.Cash Out","\n6.Exit")
        while (1):
            c = int(input("Choose:\n"))
            if (c == 1):
                d = int(input("Enter the quantity:\n"))
                self.r = self.r + 2000 * d
            elif (c == 2):
                d = int(input("Enter the quantity:\n"))
                self.r = self.r + 1800 * d
            elif (c == 3):
                d = int(input("Enter the quantity:\n"))
                self.r = self.r + 2200 * d
            elif (c == 4):
                d = int(input("Enter the quantity:\n"))
                self.r = self.r + 2600 * d
            elif(c==6):
                d=int(input("enter the quantity:\n"))
                self.r=self.r+1800*d
            elif (c == 5):
                print("total:", self.r)
                if (self.r > 0):
                    print("please enter your credit card")
                    users = ['sajal', 'muzamil', 'nisha']
                    pins = ['1234', '2222', '4141']
                    amounts = [50000, 2000000, 30000]
                    count = 0
                    # while loop checks existance of the enterd username
                    print("****************************************************************************")
                    print("*******                                                              *******")
                    print("*******           Welcome to CREDIT CARD PAYMENT SYSTEM              *******")
                    print("*******                                                                *****")
                    print("****************************************************************************")
                    while True:
                        user = input('\nENTER USER NAME: ')
                        user = user.lower()
                        if user in users:
                            if user == users[0]:
                                n = 0
                            elif user == users[1]:
                                n = 1
                            else:
                                n = 2
                            break
                        else:
                            print('----------------')
                            print('****************')
                            print('INVALID USERNAME')
                            print('****************')
                            print('----------------')
                    while count < 3:

                        print('------------------')

                        print('******************')

                        pin = input('PLEASE ENTER PIN: ')

                        print('******************')

                        print('------------------')

                        if pin.isdigit():

                            if user == 'sajal':

                                if pin == pins[0]:

                                    break

                                
                                else:

                                    count += 1

                                    print('-----------')

                                    print('***********')

                                    print('INVALID PIN')

                                    print('***********')

                                    print('-----------')

                                    print()


                                if user == 'muzamil':

                                    if pin == pins[1]:

                                        break

                                    else:

                                        count += 1

                                        print('-----------')

                                        print('***********')

                                        print('INVALID PIN')

                                        print('***********')

                                        print('-----------')

                                        print()

                                                    

                                if user == 'nisha':

                                    if pin == pins[2]:

                                         break

                                    else:

                                        count += 1

                                        print('-----------')

                                        print('***********')

                                        print('INVALID PIN')

                                        print('***********')

                                        print('-----------')

                                        print()

                            else:
                                print("invalid pin")
                    while True:
                        
                        print('-------------------------------')
                        print('*******************************')
                        response = input('SELECT FROM FOLLOWING OPTIONS: \nStatement__(S) \nPAY THE BILL__(L) \nQuit_______(Q) \nType The Letter Of Your Choices: ').lower()
                        print('*******************************')
                        print('-------------------------------')
                        valid_responses = ['s','l','q']
                        response = response.lower()
                        if response == 's':
                            print('---------------------------------------------')
                            print('*********************************************')
                            print(str.capitalize(users[n]), 'YOU HAVE RS :', amounts[n],' ON YOUR ACCOUNT.')
                            print('*********************************************')
                            print('---------------------------------------------')
                        elif response == 'l':
                            if amounts[n] >= self.r:
                                if self.r<=10000:
                                    print("Your bill is:",self.r)
                                    amounts[n]=amounts[n]-self.r
                                    print("Congradulations your bill is paid")
                                    print("Your remaining balance is:",amounts[n])
                                    print("Congradulation you got the discount of RS:")
                                    print("*****Thank You Come Again!!!*****")
                                elif self.r<=20000:
                                    self.r=self.r-500
                                    print("Your bill is:",self.r)
                                    amounts[n]=amounts[n]-self.r
                                    print("Congradulations your bill is paid")
                                    print("Your remaining balance is:",amounts[n])
                                    print("Congradulation you got the discount of RS:500")
                                    print("*****Thank You Come Again!!!*****")
                                elif self.r<=30000:
                                    self.r=self.r-1500
                                    print("Your bill is:",self.r)
                                    amounts[n]=amounts[n]-self.r
                                    print("Congradulations your bill is paid")
                                    print("Your remaining balance is:",amounts[n])
                                    print("Congradulation you got the discount of RS:1500")
                                    print("*****Thank You Come Again!!!*****")
                                elif self.r<=40000:
                                    self.r=self.r-2000
                                    print("Your bill is:",self.r)
                                    amounts[n]=amounts[n]-self.r
                                    print("Congradulations your bill is paid")
                                    print("Your remaining balance is:",amounts[n])
                                    print("Congradulation you got the discount of RS:2000")
                                    print("*****Thank You Come Again!!!*****")
                                else:
                                    self.r=self.r-10000
                                    print("Your bill is:",self.r)
                                    amounts[n]=amounts[n]-self.r
                                    print("Congradulations your bill is paid")
                                    print("Your remaining balance is:",amounts[n])
                                    print("Congradulation you got the discount of RS:10000")
                                    print("*****Thank You Come Again!!!*****")
                                                             
                            else:
                                print("You have insufficient balance in your account")
                                print("please recharge your account and come again thanks")
                        
                quit()
            elif (c == 6):
                quit()
            else:
                print("Invalid option")





def main():
    a = cashieringsystem()

    while (1):

            a.shopping()





main()
# Out:
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# ******************************WELL COME TO CHASEUP MALL***************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# 	***********************WELL COME TO THE WORLD OF BRANDS***********************************
# ...
